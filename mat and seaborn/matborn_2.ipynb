# %% [markdown]
# **Create a 2D NumPy array of shape (5, 5) filled with random integers between 10 and 99.
# Then:
# Using Matplotlib, show it as a heatmap (imshow).
# Using Seaborn, show it as a heatmap too**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
array = np.random.randint(10,99,(5,5))
array
# Out:
# array([[24, 68, 58, 46, 98],
#        [81, 92, 59, 25, 37],
#        [77, 52, 55, 77, 23],
#        [56, 74, 66, 12, 86],
#        [37, 45, 56, 23, 84]])

# %%
plt.imshow(array,cmap="viridis",interpolation="nearest")
plt.colorbar()

# %%
sns.heatmap(array,annot=True)
# Out:
# <Axes: >
