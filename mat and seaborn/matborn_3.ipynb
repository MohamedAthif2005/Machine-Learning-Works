# %% [markdown]
# Generate a 1D NumPy array of 100 random numbers from a normal distribution with:
#
# mean = 50
#
# standard deviation = 10
#
# Then:
#
# Plot a histogram using Matplotlib (plt.hist).
#
# Plot the same data using Seaborn’s distplot / histplot with KDE curve.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
array = np.random.normal(loc=50,scale=10,size=100)
array
# Out:
# array([54.15246883, 56.61426191, 17.43251761, 43.53534235, 52.1311739 ,
#        63.35259287, 59.33813977, 64.43087314, 47.18629428, 41.5912186 ,
#        37.56003258, 31.79780045, 51.27257634, 38.18264777, 48.91289148,
#        53.22807809, 58.63098031, 26.22787913, 44.36943401, 44.75558563,
#        50.79194454, 49.98806191, 57.53185841, 53.8349473 , 39.38913964,
#        63.30852418, 57.02515444, 31.20954746, 47.08635053, 70.79333201,
#        62.9545701 , 60.37675143, 65.16831203, 44.00731997, 44.1204603 ,
#        51.73617435, 46.33214537, 49.32145012, 55.8239121 , 53.84993941,
#        48.8093081 , 53.3672301 , 37.40334968, 47.46818776, 48.34062908,
#        32.11931209, 50.12838222, 49.08088768, 54.88275424, 49.63496983,
#        37.11129506, 47.05589774, 34.61089013, 59.62585694, 52.13521643,
#        39.87040571, 34.54040464, 53.40817291, 57.93606815, 52.92073631,
#        39.61780561, 40.2798091 , 48.57324804, 49.31681671, 51.19654984,
# ...

# %%
plt.hist(array,bins=10)
# Out:
# (array([ 1.,  2.,  4.,  7., 10., 26., 25., 11., 12.,  2.]),
#  array([17.43251761, 22.76859905, 28.10468049, 33.44076193, 38.77684337,
#         44.11292481, 49.44900625, 54.78508769, 60.12116913, 65.45725057,
#         70.79333201]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(array,kde=True)
# Out:
# <Axes: ylabel='Count'>
